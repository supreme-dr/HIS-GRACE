# %%
import os
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
b= pd.read_csv("C:\\Users\EMMANUEL TEMITOPE\seaborn-data\\flights.csv")
print (b)
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sbn.set(rc={"figure.figsize":(16,10)})
sbn.catplot(x="year", y= "passengers", data=b, hue="month" )

# %%
sbn.catplot(x="passengers", y= "month",kind = "boxen", data=b, hue="year")

# %%
from scipy import stats

# %%
c=np.random.normal (loc = 5 , size = 100 , scale = 2)

# %%
sbn.displot(c)

# %%
b= pd.read_csv("C:\\Users\EMMANUEL TEMITOPE\seaborn-data\\flights.csv")
c= sbn.PairGrid(b)
c.map(plt.scatter)

# %%
b= pd.read_csv("C:\\Users\EMMANUEL TEMITOPE\seaborn-data\\flights.csv")
sbn.boxplot(x="passengers", y= "month",data=b, hue="year")
sbn.set (style ="dark", color_codes = True)

# %%
b= pd.read_csv("C:\\Users\EMMANUEL TEMITOPE\seaborn-data\\flights.csv")
sbn.boxplot(x="passengers", y= "month",data=b, hue="year")
sbn.set (style ="dark", color_codes = True)
sbn.despine(offset = 20, trim = True)

# %%
c= sbn.color_palette()
sbn.palplot(c)
