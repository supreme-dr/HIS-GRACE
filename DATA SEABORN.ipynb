# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_data= pd.read_csv("C:\\Users\EMMANUEL TEMITOPE\\Desktop\\flightpython.csv")
print(raw_data)
# Out:
#     Serial NO                       AIRLINE AirlineCode  Mean.Arrival.Delay  \
# 0           2          Alaska Airlines Inc.          AS           -0.976563
# 1           4          Delta Air Lines Inc.          DL            0.186754
# 2           7        Hawaiian Airlines Inc.          HA            2.023093
# 3           1        American Airlines Inc.          AA            3.451372
# 4          12               US Airways Inc.          US            3.706209
# 5          14        Southwest Airlines Co.          WN            4.374964
# 6          13                Virgin America          VX            4.737706
# 7          11         United Air Lines Inc.          UA            5.431594
# 8          10         Skywest Airlines Inc.          OO            5.845652
# 9           8  American Eagle Airlines Inc.          MQ            6.457873
# 10          5   Atlantic Southeast Airlines          EV            6.585379
# ...

# %%
print (raw_data.shape)
# Out:
# (14, 5)

# %%
an=sns.lineplot(x="Serial NO", y = "Mean.Arrival.Delay", hue="Flight Mode", data= raw_data )

# %%
an=sns.lineplot(x="Serial NO", y = "Mean.Arrival.Delay", data= raw_data, hue="Flight Mode", style="Flight Mode")

# %%
sns.set(rc={"figure.figsize":(14,10)})
sns.lineplot(x="Serial NO", y = "Mean.Arrival.Delay", data= raw_data, hue="Flight Mode", style="Flight Mode", markers=True)
# Out:
# <AxesSubplot:xlabel='Serial NO', ylabel='Mean.Arrival.Delay'>

# %%
an=sns.barplot(x="AIRLINE", y = "Mean.Arrival.Delay", data= raw_data)

# %%
an=sns.barplot(x="AIRLINE", y = "Mean.Arrival.Delay", data= raw_data)
raw_data[["AIRLINE","Mean.Arrival.Delay"]].groupby ("Mean.Arrival.Delay").agg({'AIRLINE':'sum'})
# Out:
#                                          AIRLINE
# Mean.Arrival.Delay
# -0.976563                   Alaska Airlines Inc.
#  0.186754                   Delta Air Lines Inc.
#  2.023093                 Hawaiian Airlines Inc.
#  3.451372                 American Airlines Inc.
#  3.706209                        US Airways Inc.
#  4.374964                 Southwest Airlines Co.
#  4.737706                         Virgin America
#  5.431594                  United Air Lines Inc.
#  5.845652                  Skywest Airlines Inc.
#  6.457873           American Eagle Airlines Inc.
#  6.585379            Atlantic Southeast Airlines
#  6.677861                        JetBlue Airways
#  12.504706                Frontier Airlines Inc.
#  14.471799                      Spirit Air Lines

# %%
an=sns.barplot(x="AIRLINE", y = "Mean.Arrival.Delay", data= raw_data, ci = None)

# %%
an=sns.barplot(x="AIRLINE", y = "Mean.Arrival.Delay", data= raw_data, ci = None, hue= "Flight Mode")

# %%
an=sns.barplot(y="AIRLINE", x = "Mean.Arrival.Delay", data= raw_data, ci = None, )

# %%
an=sns.barplot(y="AIRLINE", x = "Mean.Arrival.Delay", data= raw_data, ci = None, orient ="h" kind= "line")
# Out:
#   File "<ipython-input-11-a652200b406a>", line 1
#     an=sns.barplot(y="AIRLINE", x = "Mean.Arrival.Delay", data= raw_data, ci = None, orient ="h" kind= "line")
#                                                                                                     ^
# SyntaxError: invalid syntax

# %%
an=sns.barplot(y="AIRLINE", x = "Mean.Arrival.Delay", data= raw_data, ci = None, orient ="h", color = "indigo")

# %%
x=raw_data["Mean.Arrival.Delay"].values
sns.displot(x, color = "yellow")

# %%
mean= raw_data["Mean.Arrival.Delay"].mean()
mean
# Out:
# 5.391314185714286

# %%
x=raw_data["Mean.Arrival.Delay"].values
sns.displot(x, color = "yellow")
plt.axvline(mean,0,1)

# %%
an=sns.catplot(y="AIRLINE", x = "Mean.Arrival.Delay", data= raw_data, color = "black")
